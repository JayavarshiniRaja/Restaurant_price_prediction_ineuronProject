# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objs as go
import plotly.offline as py
import seaborn as sns

import matplotlib.ticker as mtick
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
zomato_data = pd.read_csv(r"C:\Users\DELLI\Downloads\Restaurant_price_prediction_ineuronProject\zomato.csv")
zomato_data
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
zomato_data.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
zomato_data.shape
# Out:
# (51717, 17)

# %%
zomato_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
zomato_data.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
zomato_data['dish_liked'].describe()
# Out:
# count       23639
# unique       5271
# top       Biryani
# freq          182
# Name: dish_liked, dtype: object

# %%
zomato_data['votes'].describe()
# Out:
# count    51717.000000
# mean       283.697527
# std        803.838853
# min          0.000000
# 25%          7.000000
# 50%         41.000000
# 75%        198.000000
# max      16832.000000
# Name: votes, dtype: float64

# %%
zomato_data.isna().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
df = zomato_data.drop(['url','phone'],axis=1)
df
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
df.duplicated().sum()
# Out:
# 43

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
df.dropna(how='any',inplace=True)
df.isnull().sum()
# Out:
# address                        0
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# location                       0
# rest_type                      0
# dish_liked                     0
# cuisines                       0
# approx_cost(for two people)    0
# reviews_list                   0
# menu_item                      0
# listed_in(type)                0
# listed_in(city)                0
# dtype: int64

# %%
df = df.rename(columns={'approx_cost(for two people)':'amount','listed_in(type)':'type',
                                  'listed_in(city)':'city'})
df.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'location', 'rest_type', 'dish_liked', 'cuisines', 'amount',
#        'reviews_list', 'menu_item', 'type', 'city'],
#       dtype='object')

# %%
df.tail()
# Out:
#                                                  address  \
# 51705  2nd Floor, Iona, Virginia Mall, Whitefield Mai...
# 51707  Bengaluru Marriott Hotel, 75, 8th Road, EPIP A...
# 51708  Keys Hotel, 6, 1st Phase Industrial Area, Near...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
#
#                                                     name online_order  \
# 51705                                 Izakaya Gastro Pub          Yes
# 51707        M Bar - Bengaluru Marriott Hotel Whitefield           No
# 51708                             Keys Cafe - Keys Hotel           No
# 51711                                            Bhagini           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
#
#       book_table    rate  votes                    location  \
# 51705        Yes  3.8 /5    128                  Whitefield
# 51707         No  3.9 /5     77                  Whitefield
# ...

# %%
df['amount'].unique()
# Out:
# array(['800', '300', '600', '700', '550', '500', '450', '650', '400',
#        '750', '200', '850', '1,200', '150', '350', '250', '1,500',
#        '1,300', '1,000', '100', '900', '1,100', '1,600', '950', '230',
#        '1,700', '1,400', '1,350', '2,200', '2,000', '1,800', '1,900',
#        '180', '330', '2,500', '2,100', '3,000', '2,800', '3,400', '40',
#        '1,250', '3,500', '4,000', '2,400', '1,450', '3,200', '6,000',
#        '1,050', '4,100', '2,300', '120', '2,600', '5,000', '3,700',
#        '1,650', '2,700', '4,500'], dtype=object)

# %%
df['amount'] = df['amount'].apply(lambda x: x.replace(',','')) #Using lambda function to replace ',' from cost
df['amount'] = df['amount'].astype(float)

# %%
print(df['amount'].unique())
# Out:
# [ 800.  300.  600.  700.  550.  500.  450.  650.  400.  750.  200.  850.
#  1200.  150.  350.  250. 1500. 1300. 1000.  100.  900. 1100. 1600.  950.
#   230. 1700. 1400. 1350. 2200. 2000. 1800. 1900.  180.  330. 2500. 2100.
#  3000. 2800. 3400.   40. 1250. 3500. 4000. 2400. 1450. 3200. 6000. 1050.
#  4100. 2300.  120. 2600. 5000. 3700. 1650. 2700. 4500.]

# %%
df['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '4.6/5', '4.0/5', '4.2/5', '3.9/5',
#        '3.0/5', '3.6/5', '2.8/5', '4.4/5', '3.1/5', '4.3/5', '2.6/5',
#        '3.3/5', '3.5/5', '3.8 /5', '3.2/5', '4.5/5', '2.5/5', '2.9/5',
#        '3.4/5', '2.7/5', '4.7/5', 'NEW', '2.4/5', '2.2/5', '2.3/5',
#        '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5', '4.1 /5', '2.9 /5',
#        '2.7 /5', '2.5 /5', '2.6 /5', '4.5 /5', '4.3 /5', '3.7 /5',
#        '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '3.4 /5', '3.6 /5',
#        '3.3 /5', '4.6 /5', '4.9 /5', '3.2 /5', '3.0 /5', '2.8 /5',
#        '3.5 /5', '3.1 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
df = df.loc[df.rate !='NEW']

# %%
df['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '4.6/5', '4.0/5', '4.2/5', '3.9/5',
#        '3.0/5', '3.6/5', '2.8/5', '4.4/5', '3.1/5', '4.3/5', '2.6/5',
#        '3.3/5', '3.5/5', '3.8 /5', '3.2/5', '4.5/5', '2.5/5', '2.9/5',
#        '3.4/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5', '4.8/5',
#        '3.9 /5', '4.2 /5', '4.0 /5', '4.1 /5', '2.9 /5', '2.7 /5',
#        '2.5 /5', '2.6 /5', '4.5 /5', '4.3 /5', '3.7 /5', '4.4 /5',
#        '4.9/5', '2.1/5', '2.0/5', '1.8/5', '3.4 /5', '3.6 /5', '3.3 /5',
#        '4.6 /5', '4.9 /5', '3.2 /5', '3.0 /5', '2.8 /5', '3.5 /5',
#        '3.1 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5', '2.1 /5',
#        '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
df.rate = df.rate.apply(lambda x: x.replace('/5',''))

# %%
df.rate
# Out:
# 0         4.1
# 1         4.1
# 2         3.8
# 3         3.7
# 4         3.8
#          ...
# 51705    3.8
# 51707    3.9
# 51708    2.8
# 51711    2.5
# 51715    4.3
# Name: rate, Length: 23248, dtype: object

# %%
x=df['book_table'].value_counts()
colors = ['#fca903', '#c72112']

diag=go.Pie(labels=x.index,values=x,textinfo="value",
            marker=dict(colors=colors,line=dict(color='#2e2828', width=3)))
layout=go.Layout(title="Booking of Table",width=500,height=500)
fig=go.Figure(data=[diag],layout=layout)
py.iplot(fig, filename='pie_chart_subplots')
# Out:
# <div>                            <div id="d1f311d0-075e-44a2-9b12-371b9968aa0f" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d1f311d0-075e-44a2-9b12-371b9968aa0f")) {                    Plotly.newPlot(                        "d1f311d0-075e-44a2-9b12-371b9968aa0f",                        [{"labels":["No","Yes"],"marker":{"colors":["#fca903","#c72112"],"line":{"color":"#2e2828","width":3}},"textinfo":"value","values":[17191,6057],"type":"pie"}],                        {"height":500,"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","widt
# ...

# %%
sns.countplot(df['online_order'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Probability of delivery in online or not')
plt.show()

# %%
plt.figure(figsize=(9,7))
sns.distplot(df['rate'],bins=10)
# Out:
# <AxesSubplot:xlabel='rate', ylabel='Density'>

# %%
df['rate'].unique()
# Out:
# array(['4.1', '3.8', '3.7', '4.6', '4.0', '4.2', '3.9', '3.0', '3.6',
#        '2.8', '4.4', '3.1', '4.3', '2.6', '3.3', '3.5', '3.8 ', '3.2',
#        '4.5', '2.5', '2.9', '3.4', '2.7', '4.7', '2.4', '2.2', '2.3',
#        '4.8', '3.9 ', '4.2 ', '4.0 ', '4.1 ', '2.9 ', '2.7 ', '2.5 ',
#        '2.6 ', '4.5 ', '4.3 ', '3.7 ', '4.4 ', '4.9', '2.1', '2.0', '1.8',
#        '3.4 ', '3.6 ', '3.3 ', '4.6 ', '4.9 ', '3.2 ', '3.0 ', '2.8 ',
#        '3.5 ', '3.1 ', '4.8 ', '2.3 ', '4.7 ', '2.4 ', '2.1 ', '2.2 ',
#        '2.0 ', '1.8 '], dtype=object)

# %%
df['rate'].min()
# Out:
# '1.8'

# %%
df['rate'].max()
# Out:
# '4.9 '

# %%
df['rate']=df['rate'].astype(float)

# %%
((df['rate']>=1) & (df['rate']<2)).sum()
# Out:
# 5

# %%
((df['rate']>=2) & (df['rate']<3)).sum()
# Out:
# 1179

# %%
((df['rate']>=3) & (df['rate']<4)).sum()
# Out:
# 10153

# %%
(df['rate']>=4).sum()
# Out:
# 11911

# %%
sns.countplot(df['type']).set_xticklabels(sns.countplot(df['type']).get_xticklabels(), rotation=90, ha="right")
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Service mode')
# Out:
# Text(0.5, 1.0, 'Service mode')

# %%
from plotly.offline import iplot

# %%
trace0=go.Box(y=df['amount'],name="accepting online orders",marker = dict(color = 'rgb(113, 10, 100)',))
data=[trace0]
layout=go.Layout(title="BOX PLOT",width=600,height=600,yaxis=dict(title="Price"))
fig=go.Figure(data=data,layout=layout)
py.iplot(fig)
# Out:
# <div>                            <div id="cd24b789-951d-47d8-84bd-ec6c09ee59d9" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cd24b789-951d-47d8-84bd-ec6c09ee59d9")) {                    Plotly.newPlot(                        "cd24b789-951d-47d8-84bd-ec6c09ee59d9",                        [{"marker":{"color":"rgb(113, 10, 100)"},"name":"accepting online orders","y":[800.0,800.0,800.0,300.0,600.0,600.0,600.0,700.0,550.0,500.0,600.0,500.0,450.0,800.0,650.0,800.0,700.0,300.0,400.0,500.0,600.0,550.0,600.0,500.0,750.0,500.0,650.0,600.0,750.0,200.0,500.0,800.0,600.0,400.0,300.0,450.0,850.0,300.0,400.0,750.0,450.0,450.0,800.0,800.0,800.0,850.0,400.0,1200.0,300.0,300.0,150.0,350.0,400.0,600.0,600.0,800.0,300.0,400.0,300.0,200.0,400.0,300.0,450.0,800.0,500
# ...

# %%
q1 = df['amount'].quantile(0.25)
q3 = df['amount'].quantile(0.75)
IQR = q3 -q1
le = q1 - (1.5 * IQR)
ue = q3 + (1.5 * IQR)
df['amount'] = np.where(df['amount']>ue,ue,np.where(df['amount']<le,le,df['amount']))

# %%
sns.boxplot(df.amount)
# Out:
# <AxesSubplot:xlabel='amount'>

# %%
var = sns.pairplot(df)

# %%
hm = df.corr()
var2 = sns.heatmap(hm,annot = True)
var2
# Out:
# <AxesSubplot:>

# %%
import re
df.index=range(df.shape[0])
likes=[]
for i in range(df.shape[0]):
    array_split=re.split(',',df['dish_liked'][i])
    for item in array_split:
        likes.append(item)

# %%
df.index=range(df.shape[0])

# %%
df.index
# Out:
# RangeIndex(start=0, stop=23248, step=1)

# %%
print(" Most liked dishes ")
favourite_food = pd.Series(likes).value_counts()
favourite_food.head(30)
# Out:
#  Most liked dishes
#  Pasta              2692
#  Pizza              1915
#  Cocktails          1880
#  Burgers            1736
#  Mocktails          1623
#  Biryani            1307
#  Sandwiches         1287
# Burgers             1256
#  Coffee             1184
#  Nachos             1170
#  Fish               1116
#  Paratha            1107
#  Salads             1055
#  Chicken Biryani    1004
# Cocktails            891
#  Fries               876
#  Noodles             854
#  Beer                835
#  Mutton Biryani      832
#  Tea                 819
# Coffee               801
#  Sandwich            788
#  Butter Chicken      782
#  Thali               770
# Biryani              749
# Pizza                747
#  Roti                729
#  Brownie             726
#  Salad               677
#  Hot Chocolate       672
# dtype: int64

# %%
plt.figure(figsize=(14,6))
rest=df['rest_type'].value_counts()[:20]
sns.barplot(rest,rest.index)
plt.title("Restaurant types")
plt.xlabel("count")
# Out:
# Text(0.5, 0, 'count')

# %%
df.head()
# Out:
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table  rate  votes      location            rest_type  \
# 0          Yes        Yes   4.1    775  Banashankari        Casual Dining
# 1          Yes         No   4.1    787  Banashankari        Casual Dining
# 2          Yes         No   3.8    918  Banashankari  Cafe, Casual Dining
# 3           No         No   3.7     88  Banashankari          Quick Bites
# 4           No         No   3.8    166  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# ...

# %%
df.online_order[df.online_order == 'Yes'] = 1 
df.online_order[df.online_order == 'No'] = 0

# %%
df.online_order.value_counts()
# Out:
# 1    16378
# 0     6870
# Name: online_order, dtype: int64

# %%
df.online_order = pd.to_numeric(df.online_order)

# %%
df.book_table[df.book_table == 'Yes'] = 1 
df.book_table[df.book_table == 'No'] = 0

# %%
df.book_table = pd.to_numeric(df.book_table)

# %%
df.book_table.value_counts()
# Out:
# 0    17191
# 1     6057
# Name: book_table, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df.location = le.fit_transform(df.location)
df.rest_type = le.fit_transform(df.rest_type)
df.cuisines = le.fit_transform(df.cuisines)
df.menu_item = le.fit_transform(df.menu_item)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import  ExtraTreesRegressor
from sklearn.model_selection import train_test_split

# %%
df.head()
# Out:
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#    online_order  book_table  rate  votes  location  rest_type  \
# 0             1           1   4.1    775         1         20
# 1             1           0   4.1    787         1         20
# 2             1           0   3.8    918         1         16
# 3             0           0   3.7     88         1         62
# 4             0           0   3.8    166         4         20
#
#                                           dish_liked  cuisines  amount  \
# ...

# %%
my_data=df.iloc[:,[2,3,4,5,6,7,9,10,12]]
my_data.to_csv('Zomato_df.csv')

# %%
x = df.iloc[:,[2,3,5,6,7,9,10,12]]
x.head()
# Out:
#    online_order  book_table  votes  location  rest_type  cuisines  amount  \
# 0             1           1    775         1         20      1386   800.0
# 1             1           0    787         1         20       594   800.0
# 2             1           0    918         1         16       484   800.0
# 3             0           0     88         1         62      1587   300.0
# 4             0           0    166         4         20      1406   600.0
#
#    menu_item
# 0       5047
# 1       5047
# 2       5047
# 3       5047
# 4       5047

# %%
y = df['rate']
y
# Out:
# 0        4.1
# 1        4.1
# 2        3.8
# 3        3.7
# 4        3.8
#         ...
# 23243    3.8
# 23244    3.9
# 23245    2.8
# 23246    2.5
# 23247    4.3
# Name: rate, Length: 23248, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.3,random_state=10)

# %%
lr_model=LinearRegression()
lr_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
y_pred=lr_model.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.22704589070362213

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
RF_Model=RandomForestRegressor(n_estimators=650,random_state=245,min_samples_leaf=.0001)
RF_Model.fit(x_train,y_train)
y_predict=RF_Model.predict(x_test)
r2_score(y_test,y_predict)
# Out:
# 0.881204620466682

# %%
#ExtraTrees Regressor has highest r2_score

from sklearn.ensemble import  ExtraTreesRegressor
ET_Model=ExtraTreesRegressor(n_estimators = 120)
ET_Model.fit(x_train,y_train)
y_predict=ET_Model.predict(x_test)


from sklearn.metrics import r2_score
r2_score(y_test,y_predict)
# Out:
# 0.9333680549517285

# %%
import pickle
pickle.dump(ET_Model, open('model.pkl','wb'))
model=pickle.load(open('model.pkl','rb'))
